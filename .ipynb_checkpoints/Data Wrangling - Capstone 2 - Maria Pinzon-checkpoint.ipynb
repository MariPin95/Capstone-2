# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Data Collection: Data loading and data joining (if necessary)

# %%
# Open csv file
file = 'Data/masterdatatoupload.csv'
df = pd.read_csv(file, encoding = 'latin1')
print(df.head())
# Out:
#     country                                     utility name utility code  \
# 0  Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 1  Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 2  Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 3  Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 4  Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
#
#   utility ID  year   Type of connection  \
# 0     209001  1994  Elec - Distribution
# 1     209001  1995  Elec - Distribution
# 2     209001  1996  Elec - Distribution
# 3     209001  1997  Elec - Distribution
# 4     209001  1998  Elec - Distribution
#
#    Total number of connections (residential and non-residential) in the utility area  \
# 0                                             589008
# 1                                             710188
# 2                                             785280
# 3                                             850947
# 4                                             897494
#
#   Total Number of residential connections in the utility area  \
# 0                                                NaN
# 1                                             579691
# 2                                             647040
# 3                                             707179
# 4                                             749033
#
#   Total electricity sold per year (MWh) Length of distribution network (km)   \
# 0                           2961442.739                                24046
# 1                           3605894.515                             33415.54
# 2                           3802143.296                             39952.04
# 3                           3973477.997                             45892.74
# 4                           4079504.871                              48422.2
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households  \
# 0                                                NaN
# 1                                              0.694
# 2                                              0.747
# 3                                               0.79
# 4                                              0.816
#
#   Number of customer complaints per year  \
# 0                                    NaN
# 1                                  43333
# 2                                  45118
# 3                                  49173
# 4                                  49834
#
#   Average duration between customer complaint and the solution of the problem (hours)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Average residential tariff (local nominal currency / MWh)  \
# 0                                                NaN
# 1                                              95460
# 2                                             117960
# 3                                             135140
# 4                                             159890
#
#   Average industrial tariff (local nominal currency / MWh)  \
# 0                                                NaN
# 1                                              68920
# 2                                              85230
# 3                                              95020
# 4                                             110890
#
#   Installation Cost (residential) local nominal currency  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Installation Cost (Industrial) local nominal currency Year of privatization  \
# 0                                                NaN                        0
# 1                                                NaN                        0
# 2                                                NaN                        0
# 3                                                NaN                        0
# 4                                                NaN                        0
#
#   Residencial conexions per employee Energy sold per employee
# 0                                NaN                1441.0533
# 1                        222.1038314               1381.56878
# 2                        241.2527964              1417.652236
# 3                        256.7824982              1442.802468
# 4                        250.6803882              1365.296142
#
# [5 rows x 31 columns]

# %%
df = df.iloc[1:]

# %%
df.head()
# Out:
#     country                                     utility name utility code  \
# 1  Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 2  Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 3  Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 4  Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 5  Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
#
#   utility ID  year   Type of connection  \
# 1     209001  1995  Elec - Distribution
# 2     209001  1996  Elec - Distribution
# 3     209001  1997  Elec - Distribution
# 4     209001  1998  Elec - Distribution
# 5     209001  1999  Elec - Distribution
#
#    Total number of connections (residential and non-residential) in the utility area  \
# 1                                             710188
# 2                                             785280
# 3                                             850947
# 4                                             897494
# 5                                             856545
#
#   Total Number of residential connections in the utility area  \
# 1                                             579691
# 2                                             647040
# 3                                             707179
# 4                                             749033
# 5                                             719159
#
#   Total electricity sold per year (MWh) Length of distribution network (km)   \
# 1                           3605894.515                             33415.54
# 2                           3802143.296                             39952.04
# 3                           3973477.997                             45892.74
# 4                           4079504.871                              48422.2
# 5                           4815296.785                             50637.75
#
#    ...  \
# 1  ...
# 2  ...
# 3  ...
# 4  ...
# 5  ...
#
#   Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households  \
# 1                                              0.694
# 2                                              0.747
# 3                                               0.79
# 4                                              0.816
# 5                                              0.823
#
#   Number of customer complaints per year  \
# 1                                  43333
# 2                                  45118
# 3                                  49173
# 4                                  49834
# 5                                  38173
#
#   Average duration between customer complaint and the solution of the problem (hours)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Average residential tariff (local nominal currency / MWh)  \
# 1                                              95460
# 2                                             117960
# 3                                             135140
# 4                                             159890
# 5                                        161702.9087
#
#   Average industrial tariff (local nominal currency / MWh)  \
# 1                                              68920
# 2                                              85230
# 3                                              95020
# 4                                             110890
# 5                                        98855.26838
#
#   Installation Cost (residential) local nominal currency  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Installation Cost (Industrial) local nominal currency Year of privatization  \
# 1                                                NaN                        0
# 2                                                NaN                        0
# 3                                                NaN                        0
# 4                                                NaN                        0
# 5                                                NaN                        0
#
#   Residencial conexions per employee Energy sold per employee
# 1                        222.1038314               1381.56878
# 2                        241.2527964              1417.652236
# 3                        256.7824982              1442.802468
# 4                        250.6803882              1365.296142
# 5                        240.2000668              1608.315559
#
# [5 rows x 31 columns]

# %%
# Create a dictionary comprehension to compress columns names
col_dict = {c[0]:c[1] for c in enumerate(df.columns)}
col_dict
# Out:
# {0: 'country',
#  1: 'utility name',
#  2: 'utility code',
#  3: 'utility ID',
#  4: 'year',
#  5: 'Type of connection',
#  6: ' Total number of connections (residential and non-residential) in the utility area',
#  7: 'Total Number of residential connections in the utility area',
#  8: 'Total electricity sold per year (MWh)',
#  9: 'Length of distribution network (km) ',
#  10: 'Total number of employees ',
#  11: 'Average wholesale price paid per MWh (local nominal currency)',
#  12: 'Average transmission charges per MWh purchased (local nominal currency)',
#  13: 'OPEX (operation expenditures) of the distribution services (local nominal currency)',
#  14: 'CAPEX (captial expenditures) of the distribution services (local nominal currency) ',
#  15: 'TOTEX (total expenditures) of the distribution network (local nominal currency)',
#  16: 'Energy losses in distribution per year (due to technical losses and illegal connections) %',
#  17: 'Energy losses in distribution per year due to technical losses %',
#  18: 'Energy losses in distribution per year due to non-technical losses (illegal connections) %',
#  19: 'Average duration of interruptions per subscriber (hours/year)',
#  20: 'Average frequency of interruptions per subscriber (# interruptions / year)',
#  21: 'Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households',
#  22: 'Number of customer complaints per year',
#  23: 'Average duration between customer complaint and the solution of the problem (hours)',
#  24: 'Average residential tariff (local nominal currency / MWh)',
#  25: 'Average industrial tariff (local nominal currency / MWh)',
#  26: 'Installation Cost (residential) local nominal currency',
#  27: 'Installation Cost (Industrial) local nominal currency',
#  28: 'Year of privatization',
#  29: 'Residencial conexions per employee',
#  30: 'Energy sold per employee'}

# %%
# Condense column names
new_cols = {col_dict[1]:'utility_name',col_dict[2]:'utility_code',col_dict[3]:'utility_ID',col_dict[5]:'connection_type',
           col_dict[6]:'total_number_connections',col_dict[7]:'residential_connections',col_dict[8]:'electricity_sold_year_MWh',
           col_dict[9]:'distribution_length_km', col_dict[10]:'num_employees',col_dict[11]:'avg_price_MWh_local', 
            col_dict[12]:'avg_transmission_charge_MWh_local',col_dict[13]:'OPEX_local',col_dict[14]:'CAPEX_local',
           col_dict[15]:'TOTEX_local',col_dict[16]:'energy_losses_technical&nontechnical_%',col_dict[17]:'energy_losses_technical_%',
           col_dict[18]:'energy_losses_nontechnical_%',col_dict[19]:'avg_duration_interruptions_suscriber',
           col_dict[20]:'avg_frequency_interruptions_subscriber',col_dict[21]:'residential_coverage (#/100 households)', 
           col_dict[22]:'complaints_year', col_dict[23]:'avg_duration_solution_hr',col_dict[24]:'avg_residential_tarif_local',
           col_dict[25]:'avg_industrial_tarif_local', col_dict[26]:'installation_cost_residential_local', 
            col_dict[27]:'installation_cost_industrial_local', col_dict[28]:'privatization_year',col_dict[29]:'residential_connections_employee',
           col_dict[30]:'energy_sold_employee'}
df.rename(columns = new_cols, inplace = True)
df.columns
# Out:
# Index(['country', 'utility_name', 'utility_code', 'utility_ID', 'year',
#        'connection_type', 'total_number_connections',
#        'residential_connections', 'electricity_sold_year_MWh',
#        'distribution_length_km', 'num_employees', 'avg_price_MWh_local',
#        'avg_transmission_charge_MWh_local', 'OPEX_local', 'CAPEX_local',
#        'TOTEX_local', 'energy_losses_technical&nontechnical_%',
#        'energy_losses_technical_%', 'energy_losses_nontechnical_%',
#        'avg_duration_interruptions_suscriber',
#        'avg_frequency_interruptions_subscriber',
#        'residential_coverage (#/100 households)', 'complaints_year',
#        'avg_duration_solution_hr', 'avg_residential_tarif_local',
#        'avg_industrial_tarif_local', 'installation_cost_residential_local',
#        'installation_cost_industrial_local', 'privatization_year',
#        'residential_connections_employee', 'energy_sold_employee'],
#       dtype='object')

# %%
# Explore available data for one country = Ecuador
df[df.country == "Ecuador"].T
# Out:
#                                                                                       1590  \
# country                                                                            Ecuador
# utility_name                             CORPORACION PARA LA ADMINISTRACION TEMPORAL EL...
# utility_code                                                              CATEG-D / EMELEC
# utility_ID                                                                          201014
# year                                                                                  1994
# connection_type                                                        Elec - Distribution
# total_number_connections                                                               NaN
# residential_connections                                                                NaN
# electricity_sold_year_MWh                                                              NaN
# distribution_length_km                                                                 NaN
# num_employees                                                                          NaN
# avg_price_MWh_local                                                                    NaN
# avg_transmission_charge_MWh_local                                                      NaN
# OPEX_local                                                                             NaN
# CAPEX_local                                                                            NaN
# TOTEX_local                                                                            NaN
# energy_losses_technical&nontechnical_%                                         0.234329747
# energy_losses_technical_%                                                              NaN
# energy_losses_nontechnical_%                                                           NaN
# avg_duration_interruptions_suscriber                                                   NaN
# avg_frequency_interruptions_subscriber                                                 NaN
# residential_coverage (#/100 households)                                                NaN
# complaints_year                                                                        NaN
# avg_duration_solution_hr                                                               NaN
# avg_residential_tarif_local                                                            NaN
# avg_industrial_tarif_local                                                             NaN
# installation_cost_residential_local                                                    NaN
# installation_cost_industrial_local                                                     NaN
# privatization_year                                                                       1
# residential_connections_employee                                                       NaN
# energy_sold_employee                                                                   NaN
#
#                                                                                       1591  \
# country                                                                            Ecuador
# utility_name                             CORPORACION PARA LA ADMINISTRACION TEMPORAL EL...
# utility_code                                                              CATEG-D / EMELEC
# utility_ID                                                                          201014
# year                                                                                  1995
# connection_type                                                        Elec - Distribution
# total_number_connections                                                       291939.8333
# residential_connections                                                        246650.6667
# electricity_sold_year_MWh                                                          2092213
# distribution_length_km                                                                 NaN
# num_employees                                                                          NaN
# avg_price_MWh_local                                                            152664.1676
# avg_transmission_charge_MWh_local                                                      NaN
# OPEX_local                                                                             NaN
# CAPEX_local                                                                            NaN
# TOTEX_local                                                                            NaN
# energy_losses_technical&nontechnical_%                                         0.227637414
# energy_losses_technical_%                                                              NaN
# energy_losses_nontechnical_%                                                           NaN
# avg_duration_interruptions_suscriber                                                   NaN
# avg_frequency_interruptions_subscriber                                                 NaN
# residential_coverage (#/100 households)                                                NaN
# complaints_year                                                                        NaN
# avg_duration_solution_hr                                                               NaN
# avg_residential_tarif_local                                                            NaN
# avg_industrial_tarif_local                                                             NaN
# installation_cost_residential_local                                                    NaN
# installation_cost_industrial_local                                                     NaN
# privatization_year                                                                       1
# residential_connections_employee                                                       NaN
# energy_sold_employee                                                                   NaN
#
#                                                                                       1592  \
# country                                                                            Ecuador
# utility_name                             CORPORACION PARA LA ADMINISTRACION TEMPORAL EL...
# utility_code                                                              CATEG-D / EMELEC
# utility_ID                                                                          201014
# year                                                                                  1996
# connection_type                                                        Elec - Distribution
# total_number_connections                                                       307648.6667
# residential_connections                                                        258077.5833
# electricity_sold_year_MWh                                                        2191943.5
# distribution_length_km                                                                 NaN
# num_employees                                                                          NaN
# avg_price_MWh_local                                                            149385.8418
# avg_transmission_charge_MWh_local                                                      NaN
# OPEX_local                                                                             NaN
# CAPEX_local                                                                            NaN
# TOTEX_local                                                                            NaN
# energy_losses_technical&nontechnical_%                                         0.241277723
# energy_losses_technical_%                                                              NaN
# energy_losses_nontechnical_%                                                           NaN
# avg_duration_interruptions_suscriber                                                   NaN
# avg_frequency_interruptions_subscriber                                                 NaN
# residential_coverage (#/100 households)                                                NaN
# complaints_year                                                                        NaN
# avg_duration_solution_hr                                                               NaN
# avg_residential_tarif_local                                                            NaN
# avg_industrial_tarif_local                                                             NaN
# installation_cost_residential_local                                                    NaN
# installation_cost_industrial_local                                                     NaN
# privatization_year                                                                       1
# residential_connections_employee                                                       NaN
# energy_sold_employee                                                                   NaN
#
#                                                                                       1593  \
# country                                                                            Ecuador
# utility_name                             CORPORACION PARA LA ADMINISTRACION TEMPORAL EL...
# utility_code                                                              CATEG-D / EMELEC
# utility_ID                                                                          201014
# year                                                                                  1997
# connection_type                                                        Elec - Distribution
# total_number_connections                                                       316647.4167
# residential_connections                                                        265536.9167
# electricity_sold_year_MWh                                                        2415720.5
# distribution_length_km                                                                 NaN
# num_employees                                                                          NaN
# avg_price_MWh_local                                                            275049.7493
# avg_transmission_charge_MWh_local                                                      NaN
# OPEX_local                                                                             NaN
# CAPEX_local                                                                            NaN
# TOTEX_local                                                                            NaN
# energy_losses_technical&nontechnical_%                                         0.262868881
# energy_losses_technical_%                                                              NaN
# energy_losses_nontechnical_%                                                           NaN
# avg_duration_interruptions_suscriber                                                   NaN
# avg_frequency_interruptions_subscriber                                                 NaN
# residential_coverage (#/100 households)                                                NaN
# complaints_year                                                                        NaN
# avg_duration_solution_hr                                                               NaN
# avg_residential_tarif_local                                                            NaN
# avg_industrial_tarif_local                                                             NaN
# installation_cost_residential_local                                                    NaN
# installation_cost_industrial_local                                                     NaN
# privatization_year                                                                       1
# residential_connections_employee                                                       NaN
# energy_sold_employee                                                                   NaN
#
#                                                                                       1594  \
# country                                                                            Ecuador
# utility_name                             CORPORACION PARA LA ADMINISTRACION TEMPORAL EL...
# utility_code                                                              CATEG-D / EMELEC
# utility_ID                                                                          201014
# year                                                                                  1998
# connection_type                                                        Elec - Distribution
# total_number_connections                                                         322363.25
# residential_connections                                                        271161.6667
# electricity_sold_year_MWh                                                        2418859.4
# distribution_length_km                                                                 NaN
# num_employees                                                                          NaN
# avg_price_MWh_local                                                            299515.9967
# avg_transmission_charge_MWh_local                                                      NaN
# OPEX_local                                                                             NaN
# CAPEX_local                                                                            NaN
# TOTEX_local                                                                            NaN
# energy_losses_technical&nontechnical_%                                         0.267627518
# energy_losses_technical_%                                                              NaN
# energy_losses_nontechnical_%                                                           NaN
# avg_duration_interruptions_suscriber                                                   NaN
# avg_frequency_interruptions_subscriber                                                 NaN
# residential_coverage (#/100 households)                                                NaN
# complaints_year                                                                        NaN
# avg_duration_solution_hr                                                               NaN
# avg_residential_tarif_local                                                            NaN
# avg_industrial_tarif_local                                                             NaN
# installation_cost_residential_local                                                    NaN
# installation_cost_industrial_local                                                     NaN
# privatization_year                                                                       1
# residential_connections_employee                                                       NaN
# energy_sold_employee                                                                   NaN
#
#                                                                                       1595  \
# country                                                                            Ecuador
# utility_name                             CORPORACION PARA LA ADMINISTRACION TEMPORAL EL...
# utility_code                                                              CATEG-D / EMELEC
# utility_ID                                                                          201014
# year                                                                                  1999
# connection_type                                                        Elec - Distribution
# total_number_connections                                                       330175.3333
# residential_connections                                                          278947.75
# electricity_sold_year_MWh                                                      2285527.095
# distribution_length_km                                                            8079.418
# num_employees                                                                          NaN
# avg_price_MWh_local                                                            373333.1155
# avg_transmission_charge_MWh_local                                                      NaN
# OPEX_local                                                                        2.36E+11
# CAPEX_local                                                                            NaN
# TOTEX_local                                                                            NaN
# energy_losses_technical&nontechnical_%                                         0.238751709
# energy_losses_technical_%                                                              NaN
# energy_losses_nontechnical_%                                                           NaN
# avg_duration_interruptions_suscriber                                                   NaN
# avg_frequency_interruptions_subscriber                                                 NaN
# residential_coverage (#/100 households)                                                NaN
# complaints_year                                                                        NaN
# avg_duration_solution_hr                                                               NaN
# avg_residential_tarif_local                                                    500482.7227
# avg_industrial_tarif_local                                                     275073.7377
# installation_cost_residential_local                                            215356.0207
# installation_cost_industrial_local                                                     NaN
# privatization_year                                                                       1
# residential_connections_employee                                                       NaN
# energy_sold_employee                                                                   NaN
#
#                                                                                       1596  \
# country                                                                            Ecuador
# utility_name                             CORPORACION PARA LA ADMINISTRACION TEMPORAL EL...
# utility_code                                                              CATEG-D / EMELEC
# utility_ID                                                                          201014
# year                                                                                  2000
# connection_type                                                        Elec - Distribution
# total_number_connections                                                            335676
# residential_connections                                                             283521
# electricity_sold_year_MWh                                                      2253741.246
# distribution_length_km                                                            11630.62
# num_employees                                                                          NaN
# avg_price_MWh_local                                                            28.27178842
# avg_transmission_charge_MWh_local                                              3.751208659
# OPEX_local                                                                        15198886
# CAPEX_local                                                                    15166859.08
# TOTEX_local                                                                    30365745.08
# energy_losses_technical&nontechnical_%                                         0.244154341
# energy_losses_technical_%                                                      0.088058663
# energy_losses_nontechnical_%                                                   0.156095678
# avg_duration_interruptions_suscriber                                                   NaN
# avg_frequency_interruptions_subscriber                                                 NaN
# residential_coverage (#/100 households)                                                NaN
# complaints_year                                                                        NaN
# avg_duration_solution_hr                                                               NaN
# avg_residential_tarif_local                                                    31.64781739
# avg_industrial_tarif_local                                                     26.33619078
# installation_cost_residential_local                                            15.81815393
# installation_cost_industrial_local                                                     NaN
# privatization_year                                                                       1
# residential_connections_employee                                                       NaN
# energy_sold_employee                                                                   NaN
#
#                                                                                       1597  \
# country                                                                            Ecuador
# utility_name                             CORPORACION PARA LA ADMINISTRACION TEMPORAL EL...
# utility_code                                                              CATEG-D / EMELEC
# utility_ID                                                                          201014
# year                                                                                  2001
# connection_type                                                        Elec - Distribution
# total_number_connections                                                       340595.3333
# residential_connections                                                             287457
# electricity_sold_year_MWh                                                      2246710.882
# distribution_length_km                                                            3683.623
# num_employees                                                                          NaN
# avg_price_MWh_local                                                             57.5692024
# avg_transmission_charge_MWh_local                                              4.662760305
# OPEX_local                                                                        15198886
# CAPEX_local                                                                     16897999.8
# TOTEX_local                                                                     32096885.8
# energy_losses_technical&nontechnical_%                                         0.249716723
# energy_losses_technical_%                                                      0.087918722
# energy_losses_nontechnical_%                                                   0.161798002
# avg_duration_interruptions_suscriber                                                   NaN
# avg_frequency_interruptions_subscriber                                                 NaN
# residential_coverage (#/100 households)                                        0.613313562
# complaints_year                                                                        NaN
# avg_duration_solution_hr                                                               NaN
# avg_residential_tarif_local                                                    54.37778117
# avg_industrial_tarif_local                                                     60.58611985
# installation_cost_residential_local                                            31.64590078
# installation_cost_industrial_local                                                     NaN
# privatization_year                                                                       1
# residential_connections_employee                                                       NaN
# energy_sold_employee                                                                   NaN
#
#                                                                                       1598  \
# country                                                                            Ecuador
# utility_name                             CORPORACION PARA LA ADMINISTRACION TEMPORAL EL...
# utility_code                                                              CATEG-D / EMELEC
# utility_ID                                                                          201014
# year                                                                                  2002
# connection_type                                                        Elec - Distribution
# total_number_connections                                                            355018
# residential_connections                                                             299240
# electricity_sold_year_MWh                                                      2302288.161
# distribution_length_km                                                         3867.705217
# num_employees                                                                         1318
# avg_price_MWh_local                                                            72.30110164
# avg_transmission_charge_MWh_local                                              5.483677877
# OPEX_local                                                                     24720319.64
# CAPEX_local                                                                    21148156.51
# TOTEX_local                                                                    45868476.15
# energy_losses_technical&nontechnical_%                                         0.261405604
# energy_losses_technical_%                                                      0.090445043
# energy_losses_nontechnical_%                                                   0.170960558
# avg_duration_interruptions_suscriber                                                   NaN
# avg_frequency_interruptions_subscriber                                                 NaN
# residential_coverage (#/100 households)                                        0.626656651
# complaints_year                                                                        NaN
# avg_duration_solution_hr                                                               NaN
# avg_residential_tarif_local                                                    78.21874426
# avg_industrial_tarif_local                                                     70.07520691
# installation_cost_residential_local                                            40.45497722
# installation_cost_industrial_local                                                     NaN
# privatization_year                                                                       1
# residential_connections_employee                                               227.0409712
# energy_sold_employee                                                           1746.804371
#
#                                                                                       1599  \
# country                                                                            Ecuador
# utility_name                             CORPORACION PARA LA ADMINISTRACION TEMPORAL EL...
# utility_code                                                              CATEG-D / EMELEC
# utility_ID                                                                          201014
# year                                                                                  2003
# connection_type                                                        Elec - Distribution
# total_number_connections                                                            382642
# residential_connections                                                             324334
# electricity_sold_year_MWh                                                      2397103.971
# distribution_length_km                                                         3960.533452
# num_employees                                                                         1311
# avg_price_MWh_local                                                            76.78304572
# avg_transmission_charge_MWh_local                                              7.391213587
# OPEX_local                                                                     27885541.95
# CAPEX_local                                                                       24993773
# TOTEX_local                                                                    52879314.95
# energy_losses_technical&nontechnical_%                                         0.252792044
# energy_losses_technical_%                                                      0.092353801
# energy_losses_nontechnical_%                                                   0.160438243
# avg_duration_interruptions_suscriber                                                 20.99
# avg_frequency_interruptions_subscriber                                                  29
# residential_coverage (#/100 households)                                         0.66665894
# complaints_year                                                                        NaN
# avg_duration_solution_hr                                                               NaN
# avg_residential_tarif_local                                                    85.70685786
# avg_industrial_tarif_local                                                     68.13756383
# installation_cost_residential_local                                            40.64775201
# installation_cost_industrial_local                                                     NaN
# privatization_year                                                                       0
# residential_connections_employee                                               247.3943555
# energy_sold_employee                                                           1828.454593
#
#                                          ...  \
# country                                  ...
# utility_name                             ...
# utility_code                             ...
# utility_ID                               ...
# year                                     ...
# connection_type                          ...
# total_number_connections                 ...
# residential_connections                  ...
# electricity_sold_year_MWh                ...
# distribution_length_km                   ...
# num_employees                            ...
# avg_price_MWh_local                      ...
# avg_transmission_charge_MWh_local        ...
# OPEX_local                               ...
# CAPEX_local                              ...
# TOTEX_local                              ...
# energy_losses_technical&nontechnical_%   ...
# energy_losses_technical_%                ...
# energy_losses_nontechnical_%             ...
# avg_duration_interruptions_suscriber     ...
# avg_frequency_interruptions_subscriber   ...
# residential_coverage (#/100 households)  ...
# complaints_year                          ...
# avg_duration_solution_hr                 ...
# avg_residential_tarif_local              ...
# avg_industrial_tarif_local               ...
# installation_cost_residential_local      ...
# installation_cost_industrial_local       ...
# privatization_year                       ...
# residential_connections_employee         ...
# energy_sold_employee                     ...
#
#                                                                       3311  \
# country                                                            Ecuador
# utility_name                             EMPRESA ELECTRICA SUCUMBIOS  S.A.
# utility_code                                                     SUCUMBÍOS
# utility_ID                                                          201009
# year                                                                  1998
# connection_type                                        Elec - Distribution
# total_number_connections                                       15741.66667
# residential_connections                                        11897.08333
# electricity_sold_year_MWh                                          41633.4
# distribution_length_km                                                 NaN
# num_employees                                                          NaN
# avg_price_MWh_local                                            320995.3067
# avg_transmission_charge_MWh_local                                      NaN
# OPEX_local                                                             NaN
# CAPEX_local                                                            NaN
# TOTEX_local                                                            NaN
# energy_losses_technical&nontechnical_%                         0.245397172
# energy_losses_technical_%                                              NaN
# energy_losses_nontechnical_%                                           NaN
# avg_duration_interruptions_suscriber                                   NaN
# avg_frequency_interruptions_subscriber                                 NaN
# residential_coverage (#/100 households)                                NaN
# complaints_year                                                        NaN
# avg_duration_solution_hr                                               NaN
# avg_residential_tarif_local                                    370109.1686
# avg_industrial_tarif_local                                     326704.0012
# installation_cost_residential_local                                    NaN
# installation_cost_industrial_local                                     NaN
# privatization_year                                                       0
# residential_connections_employee                                       NaN
# energy_sold_employee                                                   NaN
#
#                                                                       3312  \
# country                                                            Ecuador
# utility_name                             EMPRESA ELECTRICA SUCUMBIOS  S.A.
# utility_code                                                     SUCUMBÍOS
# utility_ID                                                          201009
# year                                                                  1999
# connection_type                                        Elec - Distribution
# total_number_connections                                       17663.33333
# residential_connections                                        13441.41667
# electricity_sold_year_MWh                                        38900.824
# distribution_length_km                                                1755
# num_employees                                                          NaN
# avg_price_MWh_local                                              38900.824
# avg_transmission_charge_MWh_local                                      NaN
# OPEX_local                                                             NaN
# CAPEX_local                                                            NaN
# TOTEX_local                                                            NaN
# energy_losses_technical&nontechnical_%                         0.280950719
# energy_losses_technical_%                                              NaN
# energy_losses_nontechnical_%                                           NaN
# avg_duration_interruptions_suscriber                                   NaN
# avg_frequency_interruptions_subscriber                                 NaN
# residential_coverage (#/100 households)                                NaN
# complaints_year                                                        NaN
# avg_duration_solution_hr                                               NaN
# avg_residential_tarif_local                                    791509.1807
# avg_industrial_tarif_local                                     755306.0863
# installation_cost_residential_local                            125182.2263
# installation_cost_industrial_local                                     NaN
# privatization_year                                                       0
# residential_connections_employee                                       NaN
# energy_sold_employee                                                   NaN
#
#                                                                       3313  \
# country                                                            Ecuador
# utility_name                             EMPRESA ELECTRICA SUCUMBIOS  S.A.
# utility_code                                                     SUCUMBÍOS
# utility_ID                                                          201009
# year                                                                  2000
# connection_type                                        Elec - Distribution
# total_number_connections                                             19161
# residential_connections                                              14615
# electricity_sold_year_MWh                                        39390.747
# distribution_length_km                                             1793.26
# num_employees                                                          NaN
# avg_price_MWh_local                                            50.79147139
# avg_transmission_charge_MWh_local                                      NaN
# OPEX_local                                                             NaN
# CAPEX_local                                                            NaN
# TOTEX_local                                                            NaN
# energy_losses_technical&nontechnical_%                         0.320029021
# energy_losses_technical_%                                      0.049604496
# energy_losses_nontechnical_%                                   0.270424525
# avg_duration_interruptions_suscriber                                   NaN
# avg_frequency_interruptions_subscriber                                 NaN
# residential_coverage (#/100 households)                                NaN
# complaints_year                                                        NaN
# avg_duration_solution_hr                                               NaN
# avg_residential_tarif_local                                    49.37974301
# avg_industrial_tarif_local                                     67.53291871
# installation_cost_residential_local                            8.701329086
# installation_cost_industrial_local                                     NaN
# privatization_year                                                       0
# residential_connections_employee                                       NaN
# energy_sold_employee                                                   NaN
#
#                                                                       3314  \
# country                                                            Ecuador
# utility_name                             EMPRESA ELECTRICA SUCUMBIOS  S.A.
# utility_code                                                     SUCUMBÍOS
# utility_ID                                                          201009
# year                                                                  2001
# connection_type                                        Elec - Distribution
# total_number_connections                                       21026.83333
# residential_connections                                        16131.33333
# electricity_sold_year_MWh                                        38995.186
# distribution_length_km                                             1793.26
# num_employees                                                          NaN
# avg_price_MWh_local                                            83.45809429
# avg_transmission_charge_MWh_local                                      NaN
# OPEX_local                                                             NaN
# CAPEX_local                                                            NaN
# TOTEX_local                                                            NaN
# energy_losses_technical&nontechnical_%                         0.325256244
# energy_losses_technical_%                                      0.159999723
# energy_losses_nontechnical_%                                   0.165256521
# avg_duration_interruptions_suscriber                                   NaN
# avg_frequency_interruptions_subscriber                                 NaN
# residential_coverage (#/100 households)                        0.310291118
# complaints_year                                                        NaN
# avg_duration_solution_hr                                               NaN
# avg_residential_tarif_local                                    71.58287354
# avg_industrial_tarif_local                                     123.1396557
# installation_cost_residential_local                            12.89805847
# installation_cost_industrial_local                                     NaN
# privatization_year                                                       0
# residential_connections_employee                                       NaN
# energy_sold_employee                                                   NaN
#
#                                                                       3315  \
# country                                                            Ecuador
# utility_name                             EMPRESA ELECTRICA SUCUMBIOS  S.A.
# utility_code                                                     SUCUMBÍOS
# utility_ID                                                          201009
# year                                                                  2002
# connection_type                                        Elec - Distribution
# total_number_connections                                             22565
# residential_connections                                              17274
# electricity_sold_year_MWh                                      46038.55173
# distribution_length_km                                                  93
# num_employees                                                          192
# avg_price_MWh_local                                            118.8021634
# avg_transmission_charge_MWh_local                                      NaN
# OPEX_local                                                             NaN
# CAPEX_local                                                            NaN
# TOTEX_local                                                            NaN
# energy_losses_technical&nontechnical_%                         0.358228642
# energy_losses_technical_%                                      0.140003903
# energy_losses_nontechnical_%                                   0.218252619
# avg_duration_interruptions_suscriber                           4.903838051
# avg_frequency_interruptions_subscriber                         4.602869329
# residential_coverage (#/100 households)                        0.318305373
# complaints_year                                                        NaN
# avg_duration_solution_hr                                               NaN
# avg_residential_tarif_local                                    122.8388531
# avg_industrial_tarif_local                                     141.6576491
# installation_cost_residential_local                            20.19905364
# installation_cost_industrial_local                                     NaN
# privatization_year                                                       0
# residential_connections_employee                                  89.96875
# energy_sold_employee                                           239.7841236
#
#                                                                       3316  \
# country                                                            Ecuador
# utility_name                             EMPRESA ELECTRICA SUCUMBIOS  S.A.
# utility_code                                                     SUCUMBÍOS
# utility_ID                                                          201009
# year                                                                  2003
# connection_type                                        Elec - Distribution
# total_number_connections                                             25003
# residential_connections                                              18951
# electricity_sold_year_MWh                                      53431.82403
# distribution_length_km                                              725.49
# num_employees                                                          216
# avg_price_MWh_local                                            129.7257321
# avg_transmission_charge_MWh_local                                      NaN
# OPEX_local                                                             NaN
# CAPEX_local                                                            NaN
# TOTEX_local                                                            NaN
# energy_losses_technical&nontechnical_%                         0.375698373
# energy_losses_technical_%                                       0.15601094
# energy_losses_nontechnical_%                                   0.219687433
# avg_duration_interruptions_suscriber                                   NaN
# avg_frequency_interruptions_subscriber                                 NaN
# residential_coverage (#/100 households)                        0.340147976
# complaints_year                                                        NaN
# avg_duration_solution_hr                                               NaN
# avg_residential_tarif_local                                    135.6158927
# avg_industrial_tarif_local                                     146.7115941
# installation_cost_residential_local                            23.10201537
# installation_cost_industrial_local                                     NaN
# privatization_year                                                       0
# residential_connections_employee                               87.73611111
# energy_sold_employee                                           247.3695557
#
#                                                                       3317  \
# country                                                            Ecuador
# utility_name                             EMPRESA ELECTRICA SUCUMBIOS  S.A.
# utility_code                                                     SUCUMBÍOS
# utility_ID                                                          201009
# year                                                                  2004
# connection_type                                        Elec - Distribution
# total_number_connections                                             28656
# residential_connections                                              21967
# electricity_sold_year_MWh                                      65011.88545
# distribution_length_km                                          3293.70563
# num_employees                                                          223
# avg_price_MWh_local                                            110.7467871
# avg_transmission_charge_MWh_local                                      NaN
# OPEX_local                                                             NaN
# CAPEX_local                                                            NaN
# TOTEX_local                                                            NaN
# energy_losses_technical&nontechnical_%                         0.358137758
# energy_losses_technical_%                                           0.1702
# energy_losses_nontechnical_%                                   0.187937758
# avg_duration_interruptions_suscriber                                   NaN
# avg_frequency_interruptions_subscriber                                 NaN
# residential_coverage (#/100 households)                        0.382866241
# complaints_year                                                        NaN
# avg_duration_solution_hr                                               NaN
# avg_residential_tarif_local                                    120.7928844
# avg_industrial_tarif_local                                      128.638492
# installation_cost_residential_local                            19.74294569
# installation_cost_industrial_local                                     NaN
# privatization_year                                                       0
# residential_connections_employee                               98.50672646
# energy_sold_employee                                           291.5331186
#
#                                                                       3318  \
# country                                                            Ecuador
# utility_name                             EMPRESA ELECTRICA SUCUMBIOS  S.A.
# utility_code                                                     SUCUMBÍOS
# utility_ID                                                          201009
# year                                                                  2005
# connection_type                                        Elec - Distribution
# total_number_connections                                       33133.41667
# residential_connections                                              25885
# electricity_sold_year_MWh                                      77661.95224
# distribution_length_km                                         1497.351524
# num_employees                                                          228
# avg_price_MWh_local                                            94.95292055
# avg_transmission_charge_MWh_local                                      NaN
# OPEX_local                                                             NaN
# CAPEX_local                                                            NaN
# TOTEX_local                                                            NaN
# energy_losses_technical&nontechnical_%                         0.380712226
# energy_losses_technical_%                                           0.1702
# energy_losses_nontechnical_%                                   0.210512226
# avg_duration_interruptions_suscriber                            6.75719804
# avg_frequency_interruptions_subscriber                         9.507954156
# residential_coverage (#/100 households)                        0.432000871
# complaints_year                                                        NaN
# avg_duration_solution_hr                                               NaN
# avg_residential_tarif_local                                    119.7463189
# avg_industrial_tarif_local                                     12.48923029
# installation_cost_residential_local                            20.48059601
# installation_cost_industrial_local                                     NaN
# privatization_year                                                       0
# residential_connections_employee                               113.5307018
# energy_sold_employee                                           340.6225975
#
#                                                                       3319  \
# country                                                            Ecuador
# utility_name                             EMPRESA ELECTRICA SUCUMBIOS  S.A.
# utility_code                                                     SUCUMBÍOS
# utility_ID                                                          201009
# year                                                                  2006
# connection_type                                        Elec - Distribution
# total_number_connections                                             37747
# residential_connections                                              31259
# electricity_sold_year_MWh                                            87921
# distribution_length_km                                             1497.36
# num_employees                                                          228
# avg_price_MWh_local                                                  122.6
# avg_transmission_charge_MWh_local                              5.639840336
# OPEX_local                                                         4385160
# CAPEX_local                                                        3445498
# TOTEX_local                                                        7830658
# energy_losses_technical&nontechnical_%                              0.3485
# energy_losses_technical_%                                           0.1702
# energy_losses_nontechnical_%                                        0.1783
# avg_duration_interruptions_suscriber                           152.6627219
# avg_frequency_interruptions_subscriber                         50.21294689
# residential_coverage (#/100 households)                             0.6467
# complaints_year                                                       2590
# avg_duration_solution_hr                                               NaN
# avg_residential_tarif_local                                    119.4769141
# avg_industrial_tarif_local                                     122.4458876
# installation_cost_residential_local                                  23.82
# installation_cost_industrial_local                                     NaN
# privatization_year                                                       0
# residential_connections_employee                               137.1008772
# energy_sold_employee                                           385.6184211
#
#                                                                       3320
# country                                                            Ecuador
# utility_name                             EMPRESA ELECTRICA SUCUMBIOS  S.A.
# utility_code                                                     SUCUMBÍOS
# utility_ID                                                          201009
# year                                                                  2007
# connection_type                                        Elec - Distribution
# total_number_connections                                             42950
# residential_connections                                              34173
# electricity_sold_year_MWh                                            88538
# distribution_length_km                                              4024.1
# num_employees                                                          248
# avg_price_MWh_local                                                  115.8
# avg_transmission_charge_MWh_local                              5.630687104
# OPEX_local                                                         5426693
# CAPEX_local                                                            NaN
# TOTEX_local                                                            NaN
# energy_losses_technical&nontechnical_%                              0.4029
# energy_losses_technical_%                                           0.1702
# energy_losses_nontechnical_%                                        0.2327
# avg_duration_interruptions_suscriber                           163.5031701
# avg_frequency_interruptions_subscriber                         66.45329554
# residential_coverage (#/100 households)                             0.6263
# complaints_year                                                       1214
# avg_duration_solution_hr                                               NaN
# avg_residential_tarif_local                                    119.6125566
# avg_industrial_tarif_local                                     121.9618009
# installation_cost_residential_local                                  21.57
# installation_cost_industrial_local                                     NaN
# privatization_year                                                       0
# residential_connections_employee                               137.7943548
# energy_sold_employee                                           357.0080645
#
# [31 rows x 280 columns]

# %%
# Amount of individual countries
df['country'].value_counts()
# Out:
# Brazil                            1036
# Chile                              613
# Argentina                          575
# Colombia                           327
# Peru                               297
# Ecuador                            280
# Venezuela                          171
# Bolivia                            143
# Costa Rica                         112
# El Salvador                         90
# Perú                                65
# Panama                              54
# Guatemala                           54
# Republica Dominicana                39
# Nicaragua                           36
# Mexico                              30
# Paraguay                            24
# St Kitts and Nevis                  16
# Uruguay                             16
# Belize                              16
# Honduras                            13
# Jamaica                             13
# Haiti                               12
# St Vincent and the Grenadines        8
# Dominica                             8
# St Lucia                             8
# Antigua and Barbuda                  8
# Grenada                              8
# country                              1
# Name: country, dtype: int64

# %%
# Analyze utility names
df['utility_name'].unique()
# Out:
# array(['ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).',
#        'ADMINISTRACION NACIONAL DE USINAS Y TRANSMISIONES ELECTRICAS ',
#        'ADMINISTRACION PROVINCIAL DE ENERGIA DE LA PAMPA',
#        'AES CLESA Y COMPAÑÍA, S. EN C. DE C.V.',
#        'AES SUL DISTRIBUIDORA GAÚCHA DE ENERGIA S/A',
#        'ANTIGUA PUBLIC UTILITIES AUTHORITY', 'BANDEIRANTE ENERGIA S/A.',
#        'BELIZE ELECTRICITY LIMITED ', 'BOA VISTA ENERGIA S.A.',
#        'C.A. ELECTRICIDAD DE GUARENAS Y GUATIRE',
#        'C.A. ELECTRICIDAD DE VALENCIA ',
#        'C.A. ENERGIA ELECTRICA DE BARQUISIMETO',
#        'C.A. ENERGÍA ELECTRICA DE VENEZUELA ',
#        'C.A. LA ELECTRICIDAD DE CIUDAD BOLIVAR',
#        'C.A. LUZ ELECTRICA DE VENEZUELA',
#        'C.V.G. ELECTRIFICACION DEL CARONI C.A. CARACAS ',
#        'CA COMPAÑÍA LUZ ELECTRICA DEL YARACUY',
#        'CA LUZ Y FUERZA DE PUERTO CABELLO',
#        'CAIUA SERVIÇOS DE ELETRICIDADE S/A.',
#        'CENTRAIS ELETRICAS DE CARAZINHO S/A.',
#        'CENTRAIS ELETRICAS DE RONDÔNIA S/A',
#        'CENTRAIS ELETRICAS DO PARA S/A',
#        'CENTRAIS ELETRICAS MATOGROSSENSES S/A.',
#        'CENTRAIS ELETRICAS SANTA CATARINA S/A',
#        'CENTRAL HIDROELECTRICA DE CALDAS S.A. ESP',
#        'CENTRALES ELECTRICAS DE NARIÑO S.A. ESP',
#        'CENTRALES ELECTRICAS DEL CAUCA S.A. ESP',
#        'CENTRALES ELECTRICAS DEL NORTE DE SANTANDER', 'CHILECTRA S.A.',
#        'DISTRIBUIDORA ELECTRICA DE USULATAN, S.A.',
#        'DISTRIBUIDORA PARRAL S.A.  (LUZPAR LTDA.)',
#        'DOMINICA ELECTRICITY SERVICES LIMITED',
#        'EDELNOR - ZONAL CHANCAY (FORMER EDECHANCAY; BEFORE: ELECTROLIMA - ZONAL NORTE) (PRIVATIZED ON JANUARY, 1996) (SINCE 2001 DATA IS INCLUDED IN EDELNOR STATISTICS)',
#        'EDELNOR (PRIVATIZED ON JULY, 1994)',
#        "ELECTRICIDAD DE LA PAZ S.A.(FORMED ON THE BASIS OF COBEE'S DISTRIBUTION ASSETS IN LA PAZ, EL ATO AND VIACHA. SOLD BY COBEE TO OTHER PRIVATE INVESTORS IN DECEMBER 1995) (SEPARATE INFORMATION WAS AVAILABLE BEFORE 1996)",
#        'ELECTRICIDAD DE MISIONES S.A.', 'ELECTRICITE D\x92HAITI',
#        'ELECTRICITY DEPARTMENT ',
#        'ELECTRIFICADORA DE LA COSTA ATLANTICA S.A.',
#        'ELECTRIFICADORA DE SANTANDER (BUCARAMANGA)',
#        'ELECTRIFICADORA DEL CARIBE S.A. E.S.P. ',
#        'ELECTRIFICADORA DEL HUILA S.A. ESP',
#        'ELECTRIFICADORA DEL META S.A. ESP',
#        'ELECTRIFICADORA DEL TOLIMA S.A ESP',
#        'ELECTRO CENTRO S.A. (PRIVATIZED ON DECEMBER, 1998)',
#        'ELECTRO NOR OESTE S.A. (PRIVATIZED ON DECEMBER, 1998)',
#        'ELECTRO NORTE S.A. (PRIVATIZED ON DECEMBER, 1998)',
#        'ELECTRO ORIENTE S.A', 'ELECTRO PANGOA S.A.',
#        'ELECTRO PUNO S.A.A.', 'ELECTRO SUR ESTE SA',
#        'ELECTRO SUR MEDIO S.A.A.(PRIVATIZED ON FEBRUARY, 1997)',
#        'ELECTRO SUR S.A.', 'ELECTRO TOCACHE', 'ELECTRO UCAYALI S.A.',
#        'ELECTROLIMA',
#        'ELECTRONORTE MEDIO S.A.-HIDRADINA S.A.(PRIVATIZED ON DECEMBER, 1998)',
#        'ELEKTRO ELETRICIDADE E SERVIÇOS S/A.',
#        'ELETROPAULO METROPOLITANA \x96 ELETRICIDADE DE SÃO PAULO S/A',
#        'EMPRESA ANTIOQUEÑA DE ENERGIA S.A. E.S.P',
#        'EMPRESA DE DISTRIBUCIÓN ELECTRICA CHIRIQUÍ, S.A (EDECHI)',
#        'EMPRESA DE DISTRIBUCIÓN ELECTRICA METRO OESTE, S.A. (EDEMET)',
#        'EMPRESA DE DISTRIBUCIÓN ELECTRICA NORESTE',
#        'EMPRESA DE DISTRIBUICION ELECTRICA CANETE S.A.(FORMER ELECTROLIMA - ZONAL SUR) (PRIVATIZED ON JULY, 1996)',
#        'EMPRESA DE DISTRIBUICION ELECTRICA DE TUCUMAN S.A.',
#        'EMPRESA DE ELETRICIDADE DO VALE DO PARANAPANEMA',
#        'EMPRESA DE ENERGÍA DE BOYACA ESP',
#        'JUNTA ADMINISTRADORA DE SERVICIOS ELECTRICOS DE CARTAGO',
#        'LA ELECTRICIDAD DE CARACAS S.A.',
#        'LIGHT SERVIÇOS DE ELETRICIDADE S/A',
#        'LUZ ANDES S.A. (LO BARNECHEA) ',
#        'LUZ DEL SUR (PRIVATIZED ON JULY, 1994)',
#        'LUZ LINARES S.A (LUZAGRO LTDA.) ', 'LUZ Y FUERZA DEL CENTRO',
#        'MANAUS ENERGIA S/A', 'MUXFELDT MARIN & CIA. LTDA', 'NAME',
#        'NEVIS ELECTRICITY COMPANY', 'PROYECTO ESPECIAL CHAVIMOCHIC',
#        'RIO GRANDE ENERGIA S/A', 'SAELPA S/A DE ELETRIFICAÇÃO DA PARAÍBA',
#        'SERVICIOS ELECTRICOS POTOSÍ ', 'SERVICIOS ELECTRICOS RIOJA',
#        'SERVICIOS ELECTRICOS TARIJA S.A.',
#        'SERVICIOS ENERGETICOS DEL CHACO EMPRESA DEL ESTADO PROVINCIAL ',
#        'SISTEMA ELECTRICO DEL ESTADO NUEVA ESPARTA',
#        'SOCIEDAD AUSTRAL DE ELECTRICIDAD S.A.',
#        'SOCIEDAD ELECTRICA DE PIRQUE S.A. ',
#        'SOCIEDAD ELECTRICA DEL SUR OESTE S.A.',
#        'ST. LUCIA ELECTRICITY SERVICES LIMITED',
#        'ST. LUCIA ELECTRICITY SERVICES LIMITED ',
#        'ST. VINCENT ELECTRICITY SERVICES LIMITED',
#        'ST. VINCENT ELECTRICITY SERVICES LIMITED ',
#        'USINA HIDROELETRICA DE NOVA PALMA'], dtype=object)

# %%
# Clean up names
df['utility_name'] = df['utility_name'].str.upper()
df['utility_name'].unique()
# Out:
# array(['ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).',
#        'ADMINISTRACION NACIONAL DE USINAS Y TRANSMISIONES ELECTRICAS ',
#        'ADMINISTRACION PROVINCIAL DE ENERGIA DE LA PAMPA',
#        'AES CLESA Y COMPAÑÍA, S. EN C. DE C.V.',
#        'AES SUL DISTRIBUIDORA GAÚCHA DE ENERGIA S/A',
#        'ANTIGUA PUBLIC UTILITIES AUTHORITY', 'BANDEIRANTE ENERGIA S/A.',
#        'BELIZE ELECTRICITY LIMITED ', 'BOA VISTA ENERGIA S.A.',
#        'C.A. ELECTRICIDAD DE GUARENAS Y GUATIRE',
#        'C.A. ELECTRICIDAD DE VALENCIA ',
#        'C.A. ENERGIA ELECTRICA DE BARQUISIMETO',
#        'C.A. ENERGÍA ELECTRICA DE VENEZUELA ',
#        'C.A. LA ELECTRICIDAD DE CIUDAD BOLIVAR',
#        'C.A. LUZ ELECTRICA DE VENEZUELA',
#        'C.V.G. ELECTRIFICACION DEL CARONI C.A. CARACAS ',
#        'CA COMPAÑÍA LUZ ELECTRICA DEL YARACUY',
#        'CA LUZ Y FUERZA DE PUERTO CABELLO',
#        'CAIUA SERVIÇOS DE ELETRICIDADE S/A.',
#        'CENTRAIS ELETRICAS DE CARAZINHO S/A.',
#        'CENTRAIS ELETRICAS DE RONDÔNIA S/A',
#        'CENTRAIS ELETRICAS DO PARA S/A',
#        'CENTRAIS ELETRICAS MATOGROSSENSES S/A.',
#        'CENTRAIS ELETRICAS SANTA CATARINA S/A',
#        'CENTRAL HIDROELECTRICA DE CALDAS S.A. ESP',
#        'CENTRALES ELECTRICAS DE NARIÑO S.A. ESP',
#        'CENTRALES ELECTRICAS DEL CAUCA S.A. ESP',
#        'CENTRALES ELECTRICAS DEL NORTE DE SANTANDER', 'CHILECTRA S.A.',
#        'CNEE - COMPAÑÍA NACIONAL DE ENERGIA ELETRICA (SOUTHEAST REGION)',
#        'CODENSA S.A. ESP', 'COMISION FEDERAL DE ELECTRICIDAD',
#        'COMPAÑÍA CAMPOLARGUENSE DE ENERGIA',
#        'COMPAÑÍA DE ELETRICIDADE DO ACRE',
#        'COMPAÑÍA DE ELETRICIDADE DO AMAPÃ',
#        'COMPAÑÍA DE ELETRICIDADE DO ESTADO DA BAHIA',
#        'COMPAÑÍA DE ELETRICIDADE DO RIO DE JANEIRO',
#        'COMPAÑÍA DE ELETRICIDADE NOVA FRIBURGO',
#        'COMPAÑÍA DE ENERGIA ELETRICA DO ESTADO DO TOCANTINS',
#        'COMPAÑÍA DE LUZ E FORÇA MOCOCA',
#        'COMPAÑÍA ENERGETICA DA BORBOREMA',
#        'COMPAÑÍA ENERGETICA DE ALAGOAS',
#        'COMPAÑÍA ENERGETICA DE BRASÍLIA', 'COMPAÑÍA ENERGETICA DE GOIAS',
#        'COMPAÑÍA ENERGETICA DE MINAS GERAIS',
#        'COMPAÑÍA ENERGETICA DE PERNAMBUCO',
#        'COMPAÑÍA ENERGETICA DO AMAZONAS', 'COMPAÑÍA ENERGETICA DO CEARA',
#        'COMPAÑÍA ENERGETICA DO MARANHÃO', 'COMPAÑÍA ENERGETICA DO PIAUÍ',
#        'COMPAÑÍA ENERGETICA DO RIO GRANDE DO NORTE',
#        'COMPAÑÍA ESTADUAL DE ENERGIA ELETRICA',
#        'COMPAÑÍA FORÇA E LUZ CATAGUAZES - LEOPOLDINA ',
#        'COMPAÑÍA FORÇA E LUZ DO OESTE',
#        'COMPAÑÍA HIDRO ELETRICA DO SÃO FRANCISCO',
#        'COMPAÑÍA JAGUARI DE ENERGIA', 'COMPAÑÍA LUZ E FORÇA SANTA CRUZ',
#        'COMPAÑÍA PARANAENSE DE ENERGIA',
#        'COMPAÑÍA PAULISTA DE ENERGIA ELETRICA',
#        'COMPAÑÍA PAULISTA DE FORÇA E LUZ',
#        'COMPAÑÍA PAULISTA DE FORÇA E LUZ - PIRATININGA',
#        'COMPAÑÍA SUL PAULISTA DE ENERGIA ',
#        'COMPAÑÍA SUL SERGIPANA DE ELETRICIDADE',
#        'COMPAÑÍA ANONIMA DE ADMINISTRACION Y FOMENTO ELECTRICO',
#        'COMPAÑÍA DE ALUMBRADO ELECTRICO DE SAN SALVADOR, S.A.',
#        'COMPAÑÍA DE ELECTRICIDAD DEL TULUA S.A. ESP',
#        'DEPARTAMENTO MUNICIPAL DE ENERGIA DE IJUÍ',
#        'DIRECCION PROVINCIAL DE ENERGIA DE CORRIENTES',
#        'DISTRIBUIDORA DE ELECTRICIDAD DE OCCIDENTE',
#        'DISTRIBUIDORA DE ELECTRICIDAD DE ORIENTE ',
#        'DISTRIBUIDORA DE ELECTRICIDAD DEL NORTE (DISNORTE) ',
#        'DISTRIBUIDORA DE ELECTRICIDAD DEL SUR ',
#        'DISTRIBUIDORA DE ELECTRICIDAD DEL SUR (DISSUR) ',
#        'DISTRIBUIDORA ELECTRICA DE USULATAN, S.A.',
#        'DISTRIBUIDORA PARRAL S.A.  (LUZPAR LTDA.)',
#        'DOMINICA ELECTRICITY SERVICES LIMITED',
#        'EDELNOR - ZONAL CHANCAY (FORMER EDECHANCAY; BEFORE: ELECTROLIMA - ZONAL NORTE) (PRIVATIZED ON JANUARY, 1996) (SINCE 2001 DATA IS INCLUDED IN EDELNOR STATISTICS)',
#        'EDELNOR (PRIVATIZED ON JULY, 1994)',
#        "ELECTRICIDAD DE LA PAZ S.A.(FORMED ON THE BASIS OF COBEE'S DISTRIBUTION ASSETS IN LA PAZ, EL ATO AND VIACHA. SOLD BY COBEE TO OTHER PRIVATE INVESTORS IN DECEMBER 1995) (SEPARATE INFORMATION WAS AVAILABLE BEFORE 1996)",
#        'ELECTRICIDAD DE MISIONES S.A.', 'ELECTRICITE D\x92HAITI',
#        'ELECTRICITY DEPARTMENT ',
#        'ELECTRIFICADORA DE LA COSTA ATLANTICA S.A.',
#        'ELECTRIFICADORA DE SANTANDER (BUCARAMANGA)',
#        'ELECTRIFICADORA DEL CARIBE S.A. E.S.P. ',
#        'ELECTRIFICADORA DEL HUILA S.A. ESP',
#        'ELECTRIFICADORA DEL META S.A. ESP',
#        'ELECTRIFICADORA DEL TOLIMA S.A ESP',
#        'ELECTRO CENTRO S.A. (PRIVATIZED ON DECEMBER, 1998)',
#        'ELECTRO NOR OESTE S.A. (PRIVATIZED ON DECEMBER, 1998)',
#        'ELECTRO NORTE S.A. (PRIVATIZED ON DECEMBER, 1998)',
#        'ELECTRO ORIENTE S.A', 'ELECTRO PANGOA S.A.',
#        'ELECTRO PUNO S.A.A.', 'ELECTRO SUR ESTE SA',
#        'ELECTRO SUR MEDIO S.A.A.(PRIVATIZED ON FEBRUARY, 1997)',
#        'ELECTRO SUR S.A.', 'ELECTRO TOCACHE', 'ELECTRO UCAYALI S.A.',
#        'ELECTROLIMA',
#        'ELECTRONORTE MEDIO S.A.-HIDRADINA S.A.(PRIVATIZED ON DECEMBER, 1998)',
#        'ELEKTRO ELETRICIDADE E SERVIÇOS S/A.',
#        'ELETROPAULO METROPOLITANA \x96 ELETRICIDADE DE SÃO PAULO S/A',
#        'EMPRESA ANTIOQUEÑA DE ENERGIA S.A. E.S.P',
#        'EMPRESA DE DISTRIBUCIÓN ELECTRICA CHIRIQUÍ, S.A (EDECHI)',
#        'ENERGIA ELECTRICA DE LA COSTA ORIENTAL ', 'ENERGIA SAN JUAN S.A.',
#        'ENERQUINTA (CHILQUINTA ENERGIA S.A.)',
#        'ENTE PROVINCIAL DE NEUQUEN',
#        'ESPÍRITO SANTO CENTRAIS ELETRICAS S/A.',
#        'FORÇA E LUZ CORONEL VIVIDA LTDA ', 'GEDELSA',
#        'GRENADA ELECTRICITY SERVICES LIMITED',
#        'HIDROELETRICA PANAMBI S/A (HIDROPAN)',
#        'INSTITUTO COSTARRICENSE DE ELECTRICIDAD',
#        'JAMAICA PUBLIC SERVICE COMPANY LIMITED',
#        'JUNTA ADMINISTRADORA DE SERVICIOS ELECTRICOS DE CARTAGO',
#        'LA ELECTRICIDAD DE CARACAS S.A.',
#        'LIGHT SERVIÇOS DE ELETRICIDADE S/A',
#        'LUZ ANDES S.A. (LO BARNECHEA) ',
#        'LUZ DEL SUR (PRIVATIZED ON JULY, 1994)',
#        'LUZ LINARES S.A (LUZAGRO LTDA.) ', 'LUZ Y FUERZA DEL CENTRO',
#        'MANAUS ENERGIA S/A', 'MUXFELDT MARIN & CIA. LTDA', 'NAME',
#        'NEVIS ELECTRICITY COMPANY', 'PROYECTO ESPECIAL CHAVIMOCHIC',
#        'RIO GRANDE ENERGIA S/A', 'SAELPA S/A DE ELETRIFICAÇÃO DA PARAÍBA',
#        'SERVICIOS ELECTRICOS POTOSÍ ', 'SERVICIOS ELECTRICOS RIOJA',
#        'SERVICIOS ELECTRICOS TARIJA S.A.',
#        'SERVICIOS ENERGETICOS DEL CHACO EMPRESA DEL ESTADO PROVINCIAL ',
#        'SISTEMA ELECTRICO DEL ESTADO NUEVA ESPARTA',
#        'SOCIEDAD AUSTRAL DE ELECTRICIDAD S.A.',
#        'SOCIEDAD ELECTRICA DE PIRQUE S.A. ',
#        'SOCIEDAD ELECTRICA DEL SUR OESTE S.A.',
#        'ST. LUCIA ELECTRICITY SERVICES LIMITED',
#        'ST. LUCIA ELECTRICITY SERVICES LIMITED ',
#        'ST. VINCENT ELECTRICITY SERVICES LIMITED',
#        'ST. VINCENT ELECTRICITY SERVICES LIMITED ',
#        'USINA HIDROELETRICA DE NOVA PALMA'], dtype=object)

# %%
df1 = df.apply(pd.to_numeric, args=('coerce',))
print(df1)
# Out:
#       country  utility name  utility code  utility ID  year  \
# 1         NaN           NaN           NaN    201001.0  1994
# 2         NaN           NaN           NaN    201001.0  1995
# 3         NaN           NaN           NaN    201001.0  1996
# 4         NaN           NaN           NaN    201001.0  1997
# 5         NaN           NaN           NaN    201001.0  1998
# ...       ...           ...           ...         ...   ...
# 4069      NaN           NaN           NaN    208013.0  2002
# 4070      NaN           NaN           NaN    208013.0  2003
# 4071      NaN           NaN           NaN    208013.0  2004
# 4072      NaN           NaN           NaN    208013.0  2005
# 4073      NaN           NaN           NaN    208013.0  2006
#
#       Type of connection  \
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# ...                  ...
# 4069                 NaN
# 4070                 NaN
# 4071                 NaN
# 4072                 NaN
# 4073                 NaN
#
#        Total number of connections (residential and non-residential) in the utility area  \
# 1                                                   NaN
# 2                                           42936.83333
# 3                                           46121.91667
# 4                                           50461.58333
# 5                                           52293.33333
# ...                                                 ...
# 4069                                          293.00000
# 4070                                          314.00000
# 4071                                          337.00000
# 4072                                          351.00000
# 4073                                                NaN
#
#       Total Number of residential connections in the utility area  \
# 1                                                   NaN
# 2                                           36949.16667
# 3                                           40018.50000
# 4                                           43853.58333
# 5                                           45854.83333
# ...                                                 ...
# 4069                                                NaN
# 4070                                                NaN
# 4071                                                NaN
# 4072                                                NaN
# 4073                                                NaN
#
#       Total electricity sold per year (MWh)  \
# 1                                       NaN
# 2                                  118861.9
# 3                                  124118.5
# 4                                  134097.2
# 5                                  146304.8
# ...                                     ...
# 4069                             56147000.0
# 4070                             57109000.0
# 4071                             66130000.0
# 4072                             72754000.0
# 4073                                    NaN
#
#       Length of distribution network (km)   ...  \
# 1                                      NaN  ...
# 2                                      NaN  ...
# 3                                      NaN  ...
# 4                                      NaN  ...
# 5                                      NaN  ...
# ...                                    ...  ...
# 4069                                   NaN  ...
# 4070                                   NaN  ...
# 4071                                   NaN  ...
# 4072                                   NaN  ...
# 4073                                   NaN  ...
#
#       Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 4069                                                NaN
# 4070                                                NaN
# 4071                                                NaN
# 4072                                                NaN
# 4073                                                NaN
#
#       Number of customer complaints per year  \
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# ...                                      ...
# 4069                                     NaN
# 4070                                     NaN
# 4071                                     NaN
# 4072                                     NaN
# 4073                                     NaN
#
#       Average duration between customer complaint and the solution of the problem (hours)  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 4069                                                NaN
# 4070                                                NaN
# 4071                                                NaN
# 4072                                                NaN
# 4073                                                NaN
#
#       Average residential tariff (local nominal currency / MWh)  \
# 1                                                   NaN
# 2                                           49856.47636
# 3                                           72851.48198
# 4                                          289159.13550
# 5                                          298576.89580
# ...                                                 ...
# 4069                                                NaN
# 4070                                                NaN
# 4071                                                NaN
# 4072                                                NaN
# 4073                                                NaN
#
#       Average industrial tariff (local nominal currency / MWh)  \
# 1                                                   NaN
# 2                                           173503.0265
# 3                                           181621.9628
# 4                                           277406.9990
# 5                                           295955.8620
# ...                                                 ...
# 4069                                                NaN
# 4070                                                NaN
# 4071                                                NaN
# 4072                                                NaN
# 4073                                                NaN
#
#       Installation Cost (residential) local nominal currency  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 4069                                                NaN
# 4070                                                NaN
# 4071                                                NaN
# 4072                                                NaN
# 4073                                                NaN
#
#       Installation Cost (Industrial) local nominal currency  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 4069                                                NaN
# 4070                                                NaN
# 4071                                                NaN
# 4072                                                NaN
# 4073                                                NaN
#
#       Year of privatization  Residencial conexions per employee  \
# 1                       0.0                                 NaN
# 2                       0.0                                 NaN
# 3                       0.0                                 NaN
# 4                       0.0                                 NaN
# 5                       0.0                                 NaN
# ...                     ...                                 ...
# 4069                    0.0                                 NaN
# 4070                    0.0                                 NaN
# 4071                    0.0                                 NaN
# 4072                    0.0                                 NaN
# 4073                    NaN                                 NaN
#
#       Energy sold per employee
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# ...                        ...
# 4069               15824.97182
# 4070               15916.66667
# 4071               17420.96944
# 4072               18206.70671
# 4073                       NaN
#
# [4073 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4073 entries, 1 to 4073
# Data columns (total 31 columns):
#  #   Column                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                 --------------  -----
#  0   country                                                                                                                4073 non-null   object
#  1   utility name                                                                                                           0 non-null      object
#  2   utility code                                                                                                           4073 non-null   object
#  3   utility ID                                                                                                             4064 non-null   object
#  4   year                                                                                                                   4073 non-null   object
#  5   Type of connection                                                                                                     4073 non-null   object
#  6    Total number of connections (residential and non-residential) in the utility area                                     2911 non-null   object
#  7   Total Number of residential connections in the utility area                                                            2928 non-null   object
#  8   Total electricity sold per year (MWh)                                                                                  3195 non-null   object
#  9   Length of distribution network (km)                                                                                    1436 non-null   object
#  10  Total number of employees                                                                                              2555 non-null   object
#  11  Average wholesale price paid per MWh (local nominal currency)                                                          816 non-null    object
#  12  Average transmission charges per MWh purchased (local nominal currency)                                                495 non-null    object
#  13  OPEX (operation expenditures) of the distribution services (local nominal currency)                                    1282 non-null   object
#  14  CAPEX (captial expenditures) of the distribution services (local nominal currency)                                     1141 non-null   object
#  15  TOTEX (total expenditures) of the distribution network (local nominal currency)                                        1287 non-null   object
#  16  Energy losses in distribution per year (due to technical losses and illegal connections) %                             2509 non-null   object
#  17  Energy losses in distribution per year due to technical losses %                                                       552 non-null    object
#  18  Energy losses in distribution per year due to non-technical losses (illegal connections) %                             548 non-null    object
#  19  Average duration of interruptions per subscriber (hours/year)                                                          1374 non-null   object
#  20  Average frequency of interruptions per subscriber (# interruptions / year)                                             1280 non-null   object
#  21  Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households  1627 non-null   object
#  22  Number of customer complaints per year                                                                                 548 non-null    object
#  23  Average duration between customer complaint and the solution of the problem (hours)                                    334 non-null    object
#  24  Average residential tariff (local nominal currency / MWh)                                                              2165 non-null   object
#  25  Average industrial tariff (local nominal currency / MWh)                                                               1362 non-null   object
#  26  Installation Cost (residential) local nominal currency                                                                 411 non-null    object
#  27  Installation Cost (Industrial) local nominal currency                                                                  151 non-null    object
#  28  Year of privatization                                                                                                  3704 non-null   object
#  29  Residencial conexions per employee                                                                                     2164 non-null   object
#  30  Energy sold per employee                                                                                               2355 non-null   object
# dtypes: object(31)
# memory usage: 986.6+ KB

# %%
energy_data = df

# %%
ED_utility = energy_data.groupby('country')['utility_name'].value_counts()
print(ED_utility)
# Out:
# country               utility_name
# Antigua and Barbuda   ANTIGUA PUBLIC UTILITIES AUTHORITY                         8
# Argentina             EMPRESA DISTRIBUIDORA SUR S.A.                            22
#                       EMPRESA DISTRIBUIDORA Y COMERCIALIZADORA NORTE S.A.       21
#                       EMPRESA DISTRIBUIDORA DE ENERGIA LA PLATA S.A.            17
#                       EMPRESA DE DISTRIBUICION ELECTRICA DE TUCUMAN S.A.        16
#                                                                                 ..
# Venezuela             CA LUZ Y FUERZA DE PUERTO CABELLO                         13
#                       COMPAÑÍA ANONIMA DE ADMINISTRACION Y FOMENTO ELECTRICO    13
#                       ENERGIA ELECTRICA DE LA COSTA ORIENTAL                    13
#                       SISTEMA ELECTRICO DEL ESTADO NUEVA ESPARTA                13
# country               NAME                                                       1
# Name: utility_name, Length: 263, dtype: int64

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Analysis of Null values

# %%
missing = pd.concat([energy_data.isnull().sum(), 100 * energy_data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by= ['count','%'], ascending=False)
# Out:
#                                          count          %
# installation_cost_industrial_local        3921  96.268107
# avg_duration_solution_hr                  3738  91.775104
# installation_cost_residential_local       3661  89.884606
# avg_transmission_charge_MWh_local         3577  87.822244
# energy_losses_nontechnical_%              3524  86.520992
# complaints_year                           3524  86.520992
# energy_losses_technical_%                 3520  86.422784
# avg_price_MWh_local                       3256  79.941075
# CAPEX_local                               2931  71.961699
# avg_frequency_interruptions_subscriber    2792  68.548981
# OPEX_local                                2790  68.499877
# TOTEX_local                               2785  68.377118
# avg_industrial_tarif_local                2710  66.535723
# avg_duration_interruptions_suscriber      2698  66.241100
# distribution_length_km                    2637  64.743432
# residential_coverage (#/100 households)   2445  60.029462
# residential_connections_employee          1908  46.845077
# avg_residential_tarif_local               1907  46.820525
# energy_sold_employee                      1718  42.180211
# energy_losses_technical&nontechnical_%    1564  38.399214
# num_employees                             1518  37.269826
# total_number_connections                  1162  28.529340
# residential_connections                   1144  28.087405
# electricity_sold_year_MWh                  878  21.556592
# privatization_year                         369   9.059661
# utility_ID                                   9   0.220967
# country                                      0   0.000000
# utility_name                                 0   0.000000
# utility_code                                 0   0.000000
# year                                         0   0.000000
# connection_type                              0   0.000000

# %%
# Drop columns with more than 90% of missing values
energy_data.drop(['avg_duration_solution_hr','installation_cost_industrial_local'], axis=1)
# Out:
#        country                                     utility_name utility_code  \
# 1     Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 2     Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 3     Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 4     Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# 5     Paraguay  ADMINISTRACION NACIONAL DE ELECTRICIDAD (ANDE).         ANDE
# ...        ...                                              ...          ...
# 4069    Brazil                USINA HIDROELETRICA DE NOVA PALMA    NOVAPALMA
# 4070    Brazil                USINA HIDROELETRICA DE NOVA PALMA    NOVAPALMA
# 4071    Brazil                USINA HIDROELETRICA DE NOVA PALMA    NOVAPALMA
# 4072    Brazil                USINA HIDROELETRICA DE NOVA PALMA    NOVAPALMA
# 4073    Brazil                USINA HIDROELETRICA DE NOVA PALMA    NOVAPALMA
#
#      utility_ID  year      connection_type total_number_connections  \
# 1        209001  1995  Elec - Distribution                   710188
# 2        209001  1996  Elec - Distribution                   785280
# 3        209001  1997  Elec - Distribution                   850947
# 4        209001  1998  Elec - Distribution                   897494
# 5        209001  1999  Elec - Distribution                   856545
# ...         ...   ...                  ...                      ...
# 4069      90445  2003  Elec - Distribution                      NaN
# 4070      90445  2004  Elec - Distribution                      NaN
# 4071      90445  2005  Elec - Distribution                      NaN
# 4072      90445  2006  Elec - Distribution                    13250
# 4073      90445  2007  Elec - Distribution                      NaN
#
#      residential_connections electricity_sold_year_MWh distribution_length_km  \
# 1                     579691               3605894.515               33415.54
# 2                     647040               3802143.296               39952.04
# 3                     707179               3973477.997               45892.74
# 4                     749033               4079504.871                48422.2
# 5                     719159               4815296.785               50637.75
# ...                      ...                       ...                    ...
# 4069                     NaN                       NaN                    NaN
# 4070                     NaN                       NaN                    NaN
# 4071                     NaN                       NaN                    NaN
# 4072                    7696                        51                    NaN
# 4073                     NaN                       NaN                    NaN
#
#       ... avg_duration_interruptions_suscriber  \
# 1     ...                                 8.34
# 2     ...                                18.85
# 3     ...                                12.65
# 4     ...                                17.07
# 5     ...                                 7.13
# ...   ...                                  ...
# 4069  ...                                19.35
# 4070  ...                                 19.3
# 4071  ...                                24.84
# 4072  ...                                16.82
# 4073  ...                                  NaN
#
#      avg_frequency_interruptions_subscriber  \
# 1                                     17.78
# 2                                     17.29
# 3                                     18.15
# 4                                     21.94
# 5                                     13.32
# ...                                     ...
# 4069                                  22.34
# 4070                                  24.59
# 4071                                  25.15
# 4072                                  16.22
# 4073                                    NaN
#
#      residential_coverage (#/100 households) complaints_year  \
# 1                                      0.694           43333
# 2                                      0.747           45118
# 3                                       0.79           49173
# 4                                      0.816           49834
# 5                                      0.823           38173
# ...                                      ...             ...
# 4069                                     NaN             NaN
# 4070                                     NaN             NaN
# 4071                                     NaN             NaN
# 4072                                       1             NaN
# 4073                                     NaN             NaN
#
#      avg_residential_tarif_local avg_industrial_tarif_local  \
# 1                          95460                      68920
# 2                         117960                      85230
# 3                         135140                      95020
# 4                         159890                     110890
# 5                    161702.9087                98855.26838
# ...                          ...                        ...
# 4069                      232.64                        NaN
# 4070                         NaN                        NaN
# 4071                         NaN                        NaN
# 4072                         NaN                        NaN
# 4073                         NaN                        NaN
#
#      installation_cost_residential_local privatization_year  \
# 1                                    NaN                  0
# 2                                    NaN                  0
# 3                                    NaN                  0
# 4                                    NaN                  0
# 5                                    NaN                  0
# ...                                  ...                ...
# 4069                                 NaN                  1
# 4070                                 NaN                  1
# 4071                                 NaN                  1
# 4072                                 NaN                NaN
# 4073                                 NaN                NaN
#
#      residential_connections_employee energy_sold_employee
# 1                         222.1038314           1381.56878
# 2                         241.2527964          1417.652236
# 3                         256.7824982          1442.802468
# 4                         250.6803882          1365.296142
# 5                         240.2000668          1608.315559
# ...                               ...                  ...
# 4069                              NaN                  NaN
# 4070                              NaN                  NaN
# 4071                              NaN                  NaN
# 4072                              NaN                  NaN
# 4073                              NaN                  NaN
#
# [4073 rows x 29 columns]

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Energy Sold Distribution by Country

# %%
#Specify a horizontal barplot ('barh') as kind of plot (kind=)
energy_data.country.value_counts().plot(kind='barh')
#Give the plot a helpful title of 'Country'
plt.ylabel('Country')
#Label the xaxis 'Count'
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %% [markdown]
# Brazil has the most amount of data

# %% [markdown]
# ### Numerical Data Summary

# %%
energy_data.describe().T
# Out:
#                                         count unique                  top  \
# country                                  4073     29               Brazil
# utility_name                             4073    263       CHILECTRA S.A.
# utility_code                             4073    258               EDESUR
# utility_ID                               4064    262                  340
# year                                     4073     37                 2000
# connection_type                          4073      3  Elec - Distribution
# total_number_connections                 2911   2867                 n.d.
# residential_connections                  2929   2911                 n.d.
# electricity_sold_year_MWh                3195   3125                  n.d
# distribution_length_km                   1436   1298               57.246
# num_employees                            2555   1604                    4
# avg_price_MWh_local                       817    787           56568.9968
# avg_transmission_charge_MWh_local         496    380                    0
# OPEX_local                               1283   1227              2424200
# CAPEX_local                              1142   1114                 n.d.
# TOTEX_local                              1288   1223                    0
# energy_losses_technical&nontechnical_%   2509   1735                 0.13
# energy_losses_technical_%                 553    442                 n.d.
# energy_losses_nontechnical_%              549    468                 n.d.
# avg_duration_interruptions_suscriber     1375   1221                   30
# avg_frequency_interruptions_subscriber   1281   1112                   28
# residential_coverage (#/100 households)  1628   1256                    1
# complaints_year                           549    513                    0
# avg_duration_solution_hr                  335    174                   10
# avg_residential_tarif_local              2166   1777               108.06
# avg_industrial_tarif_local               1363   1231                  120
# installation_cost_residential_local       412    329                    0
# installation_cost_industrial_local        152    127                 n.d.
# privatization_year                       3704      3                    0
# residential_connections_employee         2165   2159              #DIV/0!
# energy_sold_employee                     2355   2337              #DIV/0!
#
#                                          freq
# country                                  1036
# utility_name                               35
# utility_code                               35
# utility_ID                                 35
# year                                      256
# connection_type                          4056
# total_number_connections                    4
# residential_connections                     8
# electricity_sold_year_MWh                   4
# distribution_length_km                      8
# num_employees                              15
# avg_price_MWh_local                         4
# avg_transmission_charge_MWh_local          14
# OPEX_local                                  4
# CAPEX_local                                 6
# TOTEX_local                                19
# energy_losses_technical&nontechnical_%     15
# energy_losses_technical_%                  23
# energy_losses_nontechnical_%               23
# avg_duration_interruptions_suscriber        6
# avg_frequency_interruptions_subscriber      6
# residential_coverage (#/100 households)   139
# complaints_year                             5
# avg_duration_solution_hr                   21
# avg_residential_tarif_local                14
# avg_industrial_tarif_local                  5
# installation_cost_residential_local        18
# installation_cost_industrial_local          5
# privatization_year                       2091
# residential_connections_employee            7
# energy_sold_employee                        7

# %% [markdown]
# ## Save The Cleaned Data

# %%
# save the data to a new csv file
energy_data.to_csv('Data/energy_data_cleaned.csv')
