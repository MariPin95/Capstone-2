# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Suppress future warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
df = pd.read_csv('Data/energy_data_cleaned.csv')
df = df.iloc[:, 1:]

# %%
df.shape
# Out:
# (4073, 31)

# %%
df.head()
# Out:
#    country                     utility name utility code  utility ID  year  \
# 0  Ecuador  EMPRESA ELECTRICA LOS RIOS S.A.     LOS RIOS    201001.0  1994
# 1  Ecuador  EMPRESA ELECTRICA LOS RIOS S.A.     LOS RIOS    201001.0  1995
# 2  Ecuador  EMPRESA ELECTRICA LOS RIOS S.A.     LOS RIOS    201001.0  1996
# 3  Ecuador  EMPRESA ELECTRICA LOS RIOS S.A.     LOS RIOS    201001.0  1997
# 4  Ecuador  EMPRESA ELECTRICA LOS RIOS S.A.     LOS RIOS    201001.0  1998
#
#     Type of connection  \
# 0  Elec - Distribution
# 1  Elec - Distribution
# 2  Elec - Distribution
# 3  Elec - Distribution
# 4  Elec - Distribution
#
#    Total number of connections (residential and non-residential) in the utility area  \
# 0                                                NaN
# 1                                        42936.83333
# 2                                        46121.91667
# 3                                        50461.58333
# 4                                        52293.33333
#
#   Total Number of residential connections in the utility area  \
# 0                                                NaN
# 1                                        36949.16667
# 2                                            40018.5
# 3                                        43853.58333
# 4                                        45854.83333
#
#   Total electricity sold per year (MWh) Length of distribution network (km)   \
# 0                                   NaN                                  NaN
# 1                              118861.9                                  NaN
# 2                              124118.5                                  NaN
# 3                              134097.2                                  NaN
# 4                              146304.8                                  NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Number of customer complaints per year  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Average duration between customer complaint and the solution of the problem (hours)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Average residential tariff (local nominal currency / MWh)  \
# 0                                                NaN
# 1                                        49856.47636
# 2                                        72851.48198
# 3                                        289159.1355
# 4                                        298576.8958
#
#   Average industrial tariff (local nominal currency / MWh)  \
# 0                                                NaN
# 1                                        173503.0265
# 2                                        181621.9628
# 3                                         277406.999
# 4                                         295955.862
#
#   Installation Cost (residential) local nominal currency  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Installation Cost (Industrial) local nominal currency  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Year of privatization Residencial conexions per employee  \
# 0                   0.0                                NaN
# 1                   0.0                                NaN
# 2                   0.0                                NaN
# 3                   0.0                                NaN
# 4                   0.0                                NaN
#
#   Energy sold per employee
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['country', 'utility name', 'utility code', 'utility ID', 'year',
#        'Type of connection',
#        ' Total number of connections (residential and non-residential) in the utility area',
#        'Total Number of residential connections in the utility area',
#        'Total electricity sold per year (MWh)',
#        'Length of distribution network (km) ', 'Total number of employees ',
#        'Average wholesale price paid per MWh (local nominal currency)',
#        'Average transmission charges per MWh purchased (local nominal currency)',
#        'OPEX (operation expenditures) of the distribution services (local nominal currency)',
#        'CAPEX (captial expenditures) of the distribution services (local nominal currency) ',
#        'TOTEX (total expenditures) of the distribution network (local nominal currency)',
#        'Energy losses in distribution per year (due to technical losses and illegal connections) %',
#        'Energy losses in distribution per year due to technical losses %',
#        'Energy losses in distribution per year due to non-technical losses (illegal connections) %',
#        'Average duration of interruptions per subscriber (hours/year)',
#        'Average frequency of interruptions per subscriber (# interruptions / year)',
#        'Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households',
#        'Number of customer complaints per year',
#        'Average duration between customer complaint and the solution of the problem (hours)',
#        'Average residential tariff (local nominal currency / MWh)',
#        'Average industrial tariff (local nominal currency / MWh)',
#        'Installation Cost (residential) local nominal currency',
#        'Installation Cost (Industrial) local nominal currency',
#        'Year of privatization', 'Residencial conexions per employee',
#        'Energy sold per employee'],
#       dtype='object')

# %%
# Clean up some column names
df.rename(columns = {' Total number of connections (residential and non-residential) in the utility area': 'Total number of connections (residential and non-residential) in the utility area', 'Residencial conexions per employee':'Residential connections per employee'}, inplace = True)

# %% [markdown]
# ### Data Cleaning

# %%
missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by= ['count','%'], ascending=False)
# Out:
#                                                     count          %
# Installation Cost (Industrial) local nominal cu...   3922  96.292659
# Average duration between customer complaint and...   3739  91.799656
# Installation Cost (residential) local nominal c...   3662  89.909158
# Average transmission charges per MWh purchased ...   3578  87.846796
# Energy losses in distribution per year due to n...   3525  86.545544
# Number of customer complaints per year               3525  86.545544
# Energy losses in distribution per year due to t...   3521  86.447336
# Average wholesale price paid per MWh (local nom...   3257  79.965627
# CAPEX (captial expenditures) of the distributio...   2932  71.986251
# Average frequency of interruptions per subscrib...   2793  68.573533
# OPEX (operation expenditures) of the distributi...   2791  68.524429
# TOTEX (total expenditures) of the distribution ...   2786  68.401670
# Average industrial tariff (local nominal curren...   2711  66.560275
# Average duration of interruptions per subscribe...   2699  66.265652
# Length of distribution network (km)                  2637  64.743432
# Number of residential subscribers per 100 house...   2446  60.054014
# Residential connections per employee                 1909  46.869629
# Average residential tariff (local nominal curre...   1908  46.845077
# Energy sold per employee                             1718  42.180211
# Energy losses in distribution per year (due to ...   1564  38.399214
# Total number of employees                            1518  37.269826
# Total number of connections (residential and no...   1162  28.529340
# Total Number of residential connections in the ...   1145  28.111957
# Total electricity sold per year (MWh)                 878  21.556592
# Year of privatization                                 369   9.059661
# utility ID                                              9   0.220967
# country                                                 0   0.000000
# utility name                                            0   0.000000
# utility code                                            0   0.000000
# year                                                    0   0.000000
# Type of connection                                      0   0.000000

# %%
# Drop columns with more than 80% null values
thresh = len(df) * 0.2
df.dropna(thresh = thresh, axis=1, inplace = True)

# %%
# Create a variable for the columns to be able to handle 
columns = df.columns
id_col = dict(enumerate(columns, 0))
col_id = {v:k for k,v in id_col.items()}

# %%
id_col
# Out:
# {0: 'country',
#  1: 'utility name',
#  2: 'utility code',
#  3: 'utility ID',
#  4: 'year',
#  5: 'Type of connection',
#  6: 'Total number of connections (residential and non-residential) in the utility area',
#  7: 'Total Number of residential connections in the utility area',
#  8: 'Total electricity sold per year (MWh)',
#  9: 'Length of distribution network (km) ',
#  10: 'Total number of employees ',
#  11: 'Average wholesale price paid per MWh (local nominal currency)',
#  12: 'OPEX (operation expenditures) of the distribution services (local nominal currency)',
#  13: 'CAPEX (captial expenditures) of the distribution services (local nominal currency) ',
#  14: 'TOTEX (total expenditures) of the distribution network (local nominal currency)',
#  15: 'Energy losses in distribution per year (due to technical losses and illegal connections) %',
#  16: 'Average duration of interruptions per subscriber (hours/year)',
#  17: 'Average frequency of interruptions per subscriber (# interruptions / year)',
#  18: 'Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households',
#  19: 'Average residential tariff (local nominal currency / MWh)',
#  20: 'Average industrial tariff (local nominal currency / MWh)',
#  21: 'Year of privatization',
#  22: 'Residential connections per employee',
#  23: 'Energy sold per employee'}

# %%
# Convert numeric columns
df[columns[6:]] = df[columns[6:]].apply(pd.to_numeric, errors='coerce')

# %%
df.dtypes
# Out:
# country                                                                                                                   object
# utility name                                                                                                              object
# utility code                                                                                                              object
# utility ID                                                                                                               float64
# year                                                                                                                       int64
# Type of connection                                                                                                        object
# Total number of connections (residential and non-residential) in the utility area                                        float64
# Total Number of residential connections in the utility area                                                              float64
# Total electricity sold per year (MWh)                                                                                    float64
# Length of distribution network (km)                                                                                      float64
# Total number of employees                                                                                                float64
# Average wholesale price paid per MWh (local nominal currency)                                                            float64
# OPEX (operation expenditures) of the distribution services (local nominal currency)                                      float64
# CAPEX (captial expenditures) of the distribution services (local nominal currency)                                       float64
# TOTEX (total expenditures) of the distribution network (local nominal currency)                                          float64
# Energy losses in distribution per year (due to technical losses and illegal connections) %                               float64
# Average duration of interruptions per subscriber (hours/year)                                                            float64
# Average frequency of interruptions per subscriber (# interruptions / year)                                               float64
# Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households    float64
# Average residential tariff (local nominal currency / MWh)                                                                float64
# Average industrial tariff (local nominal currency / MWh)                                                                 float64
# Year of privatization                                                                                                    float64
# Residential connections per employee                                                                                     float64
# Energy sold per employee                                                                                                 float64
# dtype: object

# %%
# Fill in missing values with 0 for some columns
df[[columns[6], columns[7], columns[21], columns[22]]] =df[[columns[6], columns[7], columns[21], columns[22]]].fillna(0)

# %%
# Fill in missing values with mean
df.fillna(df.groupby('utility name').transform('mean'), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# country                                                                                                                     0
# utility name                                                                                                                0
# utility code                                                                                                                0
# utility ID                                                                                                                  9
# year                                                                                                                        0
# Type of connection                                                                                                          0
# Total number of connections (residential and non-residential) in the utility area                                           0
# Total Number of residential connections in the utility area                                                                 0
# Total electricity sold per year (MWh)                                                                                      14
# Length of distribution network (km)                                                                                       810
# Total number of employees                                                                                                 154
# Average wholesale price paid per MWh (local nominal currency)                                                            2011
# OPEX (operation expenditures) of the distribution services (local nominal currency)                                      1248
# CAPEX (captial expenditures) of the distribution services (local nominal currency)                                       1351
# TOTEX (total expenditures) of the distribution network (local nominal currency)                                          1347
# Energy losses in distribution per year (due to technical losses and illegal connections) %                                402
# Average duration of interruptions per subscriber (hours/year)                                                            1322
# Average frequency of interruptions per subscriber (# interruptions / year)                                               1297
# Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households    1250
# Average residential tariff (local nominal currency / MWh)                                                                 766
# Average industrial tariff (local nominal currency / MWh)                                                                 1052
# Year of privatization                                                                                                       0
# Residential connections per employee                                                                                        0
# Energy sold per employee                                                                                                  297
# dtype: int64

# %%
# Fill in rest of null values with 0 to maintain columns numeric
df.fillna(0, inplace = True)

# %%
df.isnull().sum()
# Out:
# country                                                                                                                  0
# utility name                                                                                                             0
# utility code                                                                                                             0
# utility ID                                                                                                               0
# year                                                                                                                     0
# Type of connection                                                                                                       0
# Total number of connections (residential and non-residential) in the utility area                                        0
# Total Number of residential connections in the utility area                                                              0
# Total electricity sold per year (MWh)                                                                                    0
# Length of distribution network (km)                                                                                      0
# Total number of employees                                                                                                0
# Average wholesale price paid per MWh (local nominal currency)                                                            0
# OPEX (operation expenditures) of the distribution services (local nominal currency)                                      0
# CAPEX (captial expenditures) of the distribution services (local nominal currency)                                       0
# TOTEX (total expenditures) of the distribution network (local nominal currency)                                          0
# Energy losses in distribution per year (due to technical losses and illegal connections) %                               0
# Average duration of interruptions per subscriber (hours/year)                                                            0
# Average frequency of interruptions per subscriber (# interruptions / year)                                               0
# Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households    0
# Average residential tariff (local nominal currency / MWh)                                                                0
# Average industrial tariff (local nominal currency / MWh)                                                                 0
# Year of privatization                                                                                                    0
# Residential connections per employee                                                                                     0
# Energy sold per employee                                                                                                 0
# dtype: int64

# %%
df.dtypes
# Out:
# country                                                                                                                   object
# utility name                                                                                                              object
# utility code                                                                                                              object
# utility ID                                                                                                               float64
# year                                                                                                                       int64
# Type of connection                                                                                                        object
# Total number of connections (residential and non-residential) in the utility area                                        float64
# Total Number of residential connections in the utility area                                                              float64
# Total electricity sold per year (MWh)                                                                                    float64
# Length of distribution network (km)                                                                                      float64
# Total number of employees                                                                                                float64
# Average wholesale price paid per MWh (local nominal currency)                                                            float64
# OPEX (operation expenditures) of the distribution services (local nominal currency)                                      float64
# CAPEX (captial expenditures) of the distribution services (local nominal currency)                                       float64
# TOTEX (total expenditures) of the distribution network (local nominal currency)                                          float64
# Energy losses in distribution per year (due to technical losses and illegal connections) %                               float64
# Average duration of interruptions per subscriber (hours/year)                                                            float64
# Average frequency of interruptions per subscriber (# interruptions / year)                                               float64
# Number of residential subscribers per 100 households in the concession area (Residential coverage) # / 100 households    float64
# Average residential tariff (local nominal currency / MWh)                                                                float64
# Average industrial tariff (local nominal currency / MWh)                                                                 float64
# Year of privatization                                                                                                    float64
# Residential connections per employee                                                                                     float64
# Energy sold per employee                                                                                                 float64
# dtype: object

# %% [markdown]
# ### Analysis

# %% [markdown]
# I first want to analyze the amount of residential connections in the utility area by country

# %%
countries = list(df['country'].unique())
utility_labels = df['utility name']
fig, ax = plt.subplots(nrows=len(countries), figsize=(15, len(countries)*3.5))

for i in countries:
    ind = countries.index(i)
    filt = df['country'] == i
    
    ax[ind].bar(df[filt]['utility name'], df[filt]['Total Number of residential connections in the utility area'])
    
    ax[ind].set_title(i, size = 20)
    ax[ind].set_xlabel('Utility Name')
    ax[ind].set_ylabel('Number of Residential Connections')
    ax[ind].set_xticklabels(utility_labels, rotation = 45)

plt.tight_layout()
